# %%
# load the data
df1 = pd.read_csv('forecasts.csv', parse_dates=['Timestamp'])

# Perform forecast for each category
categories = df1['Category'].unique()
category_forecasts = {}

for category in categories:
    df_category = df1[df1['Category'] == category]
    df_category = df_category.drop(columns=['Category', 'Forecast'])
    df_category.columns = ['Date', 'Production']
    df_category['Date'] = pd.to_datetime(df_category['Date'])
    df_category.set_index('Date', inplace=True)
    df_category.dropna(inplace=True)
    
    # Prepare the data
    train = df_category.iloc[:-datapoints]
    test = df_category.iloc[-datapoints:]
    
    scaler = MinMaxScaler()
    scaler.fit(train)
    scaled_train = scaler.transform(train)
    scaled_test = scaler.transform(test)
    
    generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)
    
    # Split the training data into training and validation sets
    train_size = int(len(scaled_train) * 0.8)
    val_size = len(scaled_train) - train_size
    train_generator = TimeseriesGenerator(scaled_train[:train_size], scaled_train[:train_size], length=n_input, batch_size=1)
    valid_generator = TimeseriesGenerator(scaled_train[train_size:], scaled_train[train_size:], length=n_input, batch_size=1)
    
    # Define the LSTM model
    model = Sequential()
    model.add(Input(shape=(n_input, n_features)))
    model.add(LSTM(50, activation='relu', return_sequences=True))
    model.add(LSTM(50, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
    
    # Train the model with validation and early stopping
    model.fit(train_generator, epochs=50, validation_data=valid_generator, verbose=1) #, callbacks=[early_stopping])
    
    # Make predictions
    test_predictions = []
    first_eval_batch = scaled_train[-n_input:]
    current_batch = first_eval_batch.reshape((1, n_input, n_features))
    
    for i in range(len(test)):
        current_pred = model.predict(current_batch, verbose=0)[0]
        test_predictions.append(current_pred)
        current_batch = np.append(current_batch[:, 1:, :], [[current_pred]], axis=1)
    
    true_predictions = scaler.inverse_transform(test_predictions)
    
    # Create a DataFrame for the predictions
    predicted_df = pd.DataFrame(data=true_predictions, index=test.index, columns=['Predictions'])
    
    # Make Forecast
    future_predictions = []
    current_batch = scaled_test[-n_input:].reshape((1, n_input, n_features))
    
    for i in range(12):
        current_pred = model.predict(current_batch, verbose=0)[0]
        future_predictions.append(current_pred)
        current_batch = np.append(current_batch[:, 1:, :], [[current_pred]], axis=1)
    
    future_predictions = scaler.inverse_transform(future_predictions)
    future_dates = pd.date_range(start=test.index[-1] + pd.DateOffset(months=1), periods=12, freq='MS')
    future_predicted_df = pd.DataFrame(data=future_predictions, index=future_dates, columns=['Future Predictions'])
    
    # Store the forecast results
    category_forecasts[category] = {
        'train': train,
        'test': test,
        'predicted_df': predicted_df,
        'future_predicted_df': future_predicted_df
    }

# Plot the results for each category
for category, data in category_forecasts.items():
    plt.figure(figsize=(14, 8))
    plt.plot(data['train'].index, data['train']['Production'], label='Training Data')
    plt.plot(data['test'].index, data['test']['Production'], label='Test Data')
    plt.plot(data['predicted_df'].index, data['predicted_df']['Predictions'], label='Predictions')
    plt.plot(data['future_predicted_df'].index, data['future_predicted_df']['Future Predictions'], label='Future Predictions')
    plt.title(f'Category {category}')
    plt.legend()
    plt.show()
# Out:
# Epoch 1/50
# c:\DS_ML\Personnal\timeseries-demand-forecasting\.venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.2525 - val_loss: 0.0190
# Epoch 2/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0896 - val_loss: 0.0234
# Epoch 3/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.
# Epoch 39/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0252 - val_loss: 0.0122
# Epoch 40/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0249 - val_loss: 0.0176
# Epoch 41/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0266 - val_loss: 0.0226
# Epoch 42/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0227 - val_loss: 0.0219
# Epoch 43/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122 - val_loss: 0.0131
# Epoch 44/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0340 - val_loss: 0.0214
# Epoch 45/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0155 - val_loss: 0.0213
# Epoch 46/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0204 - val_loss: 0.0106
# Epoch 47/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0255 - val_loss: 0.0120
# Epoch 48/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0415 - val_loss: 0.0118
# Epoch 49/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0313 - val_loss: 0.0137
# Epoch 50/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0181 - val_loss: 0.0091
# Epoch 1/50
# c:\DS_ML\Personnal\timeseries-demand-forecasting\.venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.1222 - val_loss: 0.0914
# Epoch 2/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0401 - val_loss: 0.1003
# Epoch 3/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0312 - val_loss: 0.0954
# Epoch 4/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0729 - val_loss: 0.0992
# Epoch 5/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0374 - val_loss: 0.0986
# Epoch 6/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0476 - val_loss: 0.0966
# Epoch 7/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0350 - val_loss: 0.1070
# Epoch 8/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0442 - val_loss: 0.1046
# Epoch 9/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0469 - val_loss: 0.0902
# Epoch 10/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0575 - val_loss: 0.0933
# Epoch 11/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0449 - val_loss: 0.0833
# Epoch 12/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0399 - val_loss: 0.0947
# Epoch 13/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0256 - val_loss: 0.0778
# Epoch 14/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0403 - val_loss: 0.0763
# Epoch 15/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0254 - val_loss: 0.0953
# Epoch 16/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0299 - val_loss: 0.0765
# Epoch 17/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0266 - val_loss: 0.1002
# Epoch 18/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0485 - val_loss: 0.0949
# Epoch 19/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0607 - val_loss: 0.0784
# Epoch 20/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0269 - val_loss: 0.1094
# Epoch 21/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0654 - val_loss: 0.0842
# Epoch 22/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0253 - val_loss: 0.0943
# Epoch 23/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0245 - val_loss: 0.0860
# Epoch 24/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0193 - val_loss: 0.0817
# Epoch 25/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0285 - val_loss: 0.1044
# Epoch 26/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0402 - val_loss: 0.0781
# Epoch 27/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0257 - val_loss: 0.0888
# Epoch 28/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0446 - val_loss: 0.0843
# Epoch 29/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0277 - val_loss: 0.1056
# Epoch 30/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0334 - val_loss: 0.0816
# Epoch 31/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0276 - val_loss: 0.0937
# Epoch 32/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0331 - val_loss: 0.0778
# Epoch 33/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0403 - val_loss: 0.0850
# Epoch 34/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0349 - val_loss: 0.0819
# Epoch 35/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0404 - val_loss: 0.0772
# Epoch 36/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0221 - val_loss: 0.0839
# Epoch 37/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0256 - val_loss: 0.0875
# Epoch 38/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0220 - val_loss: 0.0876
# Epoch 39/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0260 - val_loss: 0.0883
# Epoch 40/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0255 - val_loss: 0.0960
# Epoch 41/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0329 - val_loss: 0.0830
# Epoch 42/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0374 - val_loss: 0.0849
# Epoch 43/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0199 - val_loss: 0.0902
# Epoch 44/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0237 - val_loss: 0.0866
# Epoch 45/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0222 - val_loss: 0.0873
# Epoch 46/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0181 - val_loss: 0.0861
# Epoch 47/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0271 - val_loss: 0.0787
# Epoch 48/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0219 - val_loss: 0.0989
# Epoch 49/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0202 - val_loss: 0.0832
# Epoch 50/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0372 - val_loss: 0.0864

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt

class ForecastModel:
    def __init__(self, data_path, n_input=5, n_features=1, datapoints=12):
        self.data_path = data_path
        self.n_input = n_input
        self.n_features = n_features
        self.datapoints = datapoints
        self.scaler = MinMaxScaler()
        self.category_forecasts = {}

    def load_data(self):
        df1 = pd.read_csv(self.data_path, parse_dates=['Timestamp'])
        return df1

    def prepare_data(self, df, category):
        df_category = df[df['Category'] == category]
        df_category = df_category.drop(columns=['Category', 'Forecast'])
        df_category.columns = ['Date', 'Production']
        df_category['Date'] = pd.to_datetime(df_category['Date'])
        df_category.set_index('Date', inplace=True)
        df_category.dropna(inplace=True)
        return df_category

    def scale_data(self, train, test):
        self.scaler.fit(train)
        scaled_train = self.scaler.transform(train)
        scaled_test = self.scaler.transform(test)
        return scaled_train, scaled_test

    def create_generators(self, scaled_train):
        generator = TimeseriesGenerator(scaled_train, scaled_train, length=self.n_input, batch_size=1)
        train_size = int(len(scaled_train) * 0.8)
        train_generator = TimeseriesGenerator(scaled_train[:train_size], scaled_train[:train_size], length=self.n_input, batch_size=1)
        valid_generator = TimeseriesGenerator(scaled_train[train_size:], scaled_train[train_size:], length=self.n_input, batch_size=1)
        return generator, train_generator, valid_generator

    def build_model(self):
        model = Sequential()
        model.add(Input(shape=(self.n_input, self.n_features)))
        model.add(LSTM(50, activation='relu', return_sequences=True))
        model.add(LSTM(50, activation='relu'))
        model.add(Dropout(0.2))
        model.add(Dense(1))
        model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
        return model

    def train_model(self, model, train_generator, valid_generator):
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, min_delta=0.001, restore_best_weights=True)
        model.fit(train_generator, epochs=50, validation_data=valid_generator, verbose=1, callbacks=[early_stopping])

    def make_predictions(self, model, scaled_train, scaled_test, test):
        test_predictions = []
        first_eval_batch = scaled_train[-self.n_input:]
        current_batch = first_eval_batch.reshape((1, self.n_input, self.n_features))

        for i in range(len(test)):
            current_pred = model.predict(current_batch, verbose=0)[0]
            test_predictions.append(current_pred)
            current_batch = np.append(current_batch[:, 1:, :], [[current_pred]], axis=1)

        true_predictions = self.scaler.inverse_transform(test_predictions)
        predicted_df = pd.DataFrame(data=true_predictions, index=test.index, columns=['Predictions'])

        future_predictions = []
        current_batch = scaled_test[-self.n_input:].reshape((1, self.n_input, self.n_features))

        for i in range(12):
            current_pred = model.predict(current_batch, verbose=0)[0]
            future_predictions.append(current_pred)
            current_batch = np.append(current_batch[:, 1:, :], [[current_pred]], axis=1)

        future_predictions = self.scaler.inverse_transform(future_predictions)
        future_dates = pd.date_range(start=test.index[-1] + pd.DateOffset(months=1), periods=12, freq='MS')
        future_predicted_df = pd.DataFrame(data=future_predictions, index=future_dates, columns=['Future Predictions'])

        return predicted_df, future_predicted_df

    def plot_results(self, category, train, test, predicted_df, future_predicted_df):
        plt.figure(figsize=(14, 8))
        plt.plot(train.index, train['Production'], label='Training Data')
        plt.plot(test.index, test['Production'], label='Test Data')
        plt.plot(predicted_df.index, predicted_df['Predictions'], label='Predictions')
        plt.plot(future_predicted_df.index, future_predicted_df['Future Predictions'], label='Future Predictions')
        plt.title(f'Category {category}')
        plt.legend()
        plt.show()

    def forecast(self):
        df1 = self.load_data()
        categories = df1['Category'].unique()

        for category in categories:
            df_category = self.prepare_data(df1, category)
            train = df_category.iloc[:-self.datapoints]
            test = df_category.iloc[-self.datapoints:]
            scaled_train, scaled_test = self.scale_data(train, test)
            generator, train_generator, valid_generator = self.create_generators(scaled_train)
            model = self.build_model()
            self.train_model(model, train_generator, valid_generator)
            predicted_df, future_predicted_df = self.make_predictions(model, scaled_train, scaled_test, test)

            self.category_forecasts[category] = {
                'train': train,
                'test': test,
                'predicted_df': predicted_df,
                'future_predicted_df': future_predicted_df
            }

            self.plot_results(category, train, test, predicted_df, future_predicted_df)

if __name__ == "__main__":
    forecast_model = ForecastModel(data_path='forecasts.csv')
    forecast_model.forecast()
